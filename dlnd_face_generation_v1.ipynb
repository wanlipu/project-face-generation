# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# # can comment out after executing
# !unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    
    # resize the images into (image_size, image_size) and convert to tensor
    transform = transforms.Compose([transforms.Resize((image_size, image_size)), transforms.ToTensor()])
    
    # create dataset with datasets.ImageFolder module
    celeba_data = datasets.ImageFolder(data_dir, transform=transform)
    
    data_loader = torch.utils.data.DataLoader(dataset=celeba_data,
                                              batch_size=batch_size,
                                              shuffle=True,
                                              num_workers=0)
    
    return data_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    low = min(feature_range)
    high = max(feature_range)
    
    return x*(high-low) + low

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-1.)
# Max:  tensor(0.7255)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        
        # complete init function
        kernel_size = 4
        stride = 2
        padding = 1
        
        # save conv_dim for forward() 
        self.conv_dim = conv_dim

        # 32x32 input, in_channels 3
        self.conv1 = nn.Conv2d(3, conv_dim, kernel_size, stride, padding, bias=False)
        # 16x16 out, out_channels conv_dim
        self.conv2 = nn.Conv2d(conv_dim, conv_dim*2, kernel_size, stride, padding, bias=False)
        self.batchnorm1 = nn.BatchNorm2d(conv_dim*2)
        # 8x8 out, out_channels 2*conv_dim
        self.conv3 = nn.Conv2d(conv_dim*2, conv_dim*4, kernel_size, stride, padding, bias=False)
        self.batchnorm2 = nn.BatchNorm2d(conv_dim*4)
        # 4x4 out, out_channels 4*conv_dim (4*64 for this project)
        
        # fully-connected layer, (4*4, channels 4*conv_dim)
        self.fc = nn.Linear(conv_dim*4*4*4, 1)
        
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        
        # use leaky relu
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.batchnorm1(self.conv2(x)), 0.2)
        x = F.leaky_relu(self.batchnorm2(self.conv3(x)), 0.2)
        
        # flatten
        x = x.view(-1, self.conv_dim*4*4*4)
        
        # final output layer
        x = self.fc(x)       
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        kernel_size = 4
        stride = 2
        padding = 1
        
        # save conv_dim for forward()
        self.conv_dim = conv_dim
        
        # fully-connected layer, input z_size, output 4*4*4*conv_dim
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)

        # transpose conv layers
        # 4x4 input, in_channels 4*conv_dim
        self.t_conv1 = nn.ConvTranspose2d(conv_dim*4, conv_dim*2, kernel_size, stride, padding, bias=False)
        self.batchnorm1 = nn.BatchNorm2d(conv_dim*2)
        # 8*8 output, out_channels 2*conv_dim
        self.t_conv2 = nn.ConvTranspose2d(conv_dim*2, conv_dim, kernel_size, stride, padding, bias=False)
        self.batchnorm2 = nn.BatchNorm2d(conv_dim)
        # 16*16 output, out_channels conv_dim
        self.t_conv3 = nn.ConvTranspose2d(conv_dim, 3, kernel_size, stride, padding, bias=False)
        # 32*32 output, out_channels 3
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*4, 4, 4) # reshpae to (batch_size, depth, 4, 4)
        
        # hidden transpose conv layers + relu
        x = F.relu(self.batchnorm1(self.t_conv1(x)))
        x = F.relu(self.batchnorm2(self.t_conv2(x)))
        
        # last layer + tanh activation
        x = self.t_conv3(x)
        x = F.tanh(x)
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
from torch.nn import init

def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    
    # if the classname is 'Conv' or 'Linear'
    # initilize weights to a normal distribution, mean 0, std 0.02
    if classname in ['Conv', 'Linear']:
        init.normal_(m.weight.data, 0.0, 0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=4096, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=4096, bias=True)
#   (t_conv1): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (t_conv2): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (t_conv3): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    # calculate batch size
    batch_size = D_out.size(0)
    
    # with some sort of smoothing
    labels = torch.ones(batch_size)*0.9 
    
    if train_on_gpu:
        labels = labels.cuda()
        
    # binary cross entropy loss function
    criterion = nn.BCEWithLogitsLoss()
    
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    # calculate batch size
    batch_size = D_out.size(0)
    
    # fake labels = 0
    labels = torch.zeros(batch_size) 
    
    if train_on_gpu:
        labels = labels.cuda()
        
    # BCE With Logits Loss
    criterion = nn.BCEWithLogitsLoss()
    
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# params
lr = 0.0001
beta1=0.1
beta2=0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            
            d_optimizer.zero_grad()
            
            if train_on_gpu:
                real_images = real_images.cuda()
        
            # pass real images to discriminator
            D_real = D(real_images)
            
            # calculate loss 
            d_real_loss = real_loss(D_real)
            
            
            # generate fake images
            
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
            
            # pass z to generator to generate fake images
            fake_images = G(z)
            
            # pass fake images to discriminator
            D_fake = D(fake_images)
            
            # calculate loss
            d_fake_loss = fake_loss(D_fake)
            
            # sum up loss
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            
            g_optimizer.zero_grad()
            
            # generate fake images
            
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
                
            # pass z to generator to generate fake images
            fake_images = G(z)
            
            # pass fake images to discriminator
            D_fake = D(fake_images)
            
            # calculate loss with real_loss function
            g_loss = real_loss(D_fake)
            g_loss.backward()
            g_optimizer.step()
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
from workspace_utils import active_session

# set number of epochs 
n_epochs = 25


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
with active_session():
    losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   25] | d_loss: 1.5052 | g_loss: 1.1506
# Epoch [    1/   25] | d_loss: 0.6058 | g_loss: 2.0358
# Epoch [    1/   25] | d_loss: 0.7719 | g_loss: 1.8264
# Epoch [    1/   25] | d_loss: 0.7304 | g_loss: 1.5659
# Epoch [    1/   25] | d_loss: 0.8626 | g_loss: 1.2998
# Epoch [    1/   25] | d_loss: 0.9792 | g_loss: 1.1713
# Epoch [    1/   25] | d_loss: 1.2392 | g_loss: 0.7105
# Epoch [    1/   25] | d_loss: 0.9975 | g_loss: 1.1157
# Epoch [    1/   25] | d_loss: 1.1585 | g_loss: 0.8383
# Epoch [    1/   25] | d_loss: 0.9637 | g_loss: 1.4290
# Epoch [    1/   25] | d_loss: 1.2462 | g_loss: 0.7014
# Epoch [    1/   25] | d_loss: 1.0536 | g_loss: 1.3895
# Epoch [    1/   25] | d_loss: 1.1957 | g_loss: 0.8281
# Epoch [    1/   25] | d_loss: 1.1670 | g_loss: 1.3347
# Epoch [    1/   25] | d_loss: 1.1676 | g_loss: 1.1351
# Epoch [    2/   25] | d_loss: 1.1962 | g_loss: 0.8590
# Epoch [    2/   25] | d_loss: 1.1855 | g_loss: 0.9460
# Epoch [    2/   25] | d_loss: 1.2805 | g_loss: 0.8380
# Epoch [    2/   25] | d_loss: 1.1999 | g_loss: 0.9119
# Epoch [    2/   25] | d_loss: 1.0772 | g_loss: 1.3685
# Epoch [    2/   25] | d_loss: 1.2890 | g_loss: 1.5082
# Epoch [    2/   25] | d_loss: 1.2536 | g_loss: 1.3753
# Epoch [    2/   25] | d_loss: 1.1389 | g_loss: 0.8612
# Epoch [    2/   25] | d_loss: 1.2231 | g_loss: 0.9855
# Epoch [    2/   25] | d_loss: 1.2883 | g_loss: 0.6466
# Epoch [    2/   25] | d_loss: 1.2069 | g_loss: 1.2097
# Epoch [    2/   25] | d_loss: 1.2377 | g_loss: 1.1567
# Epoch [    2/   25] | d_loss: 1.2131 | g_loss: 1.3190
# Epoch [    2/   25] | d_loss: 1.1564 | g_loss: 0.8589
# Epoch [    2/   25] | d_loss: 1.1633 | g_loss: 1.0707
# Epoch [    3/   25] | d_loss: 1.2254 | g_loss: 0.8253
# Epoch [    3/   25] | d_loss: 1.4067 | g_loss: 1.3877
# Epoch [    3/   25] | d_loss: 1.2364 | g_loss: 0.9272
# Epoch [    3/   25] | d_loss: 1.2232 | g_loss: 0.8947
# Epoch [    3/   25] | d_loss: 1.1492 | g_loss: 0.9162
# Epoch [    3/   25] | d_loss: 1.2122 | g_loss: 0.7634
# Epoch [    3/   25] | d_loss: 1.2528 | g_loss: 1.4354
# Epoch [    3/   25] | d_loss: 1.2670 | g_loss: 0.7900
# Epoch [    3/   25] | d_loss: 1.2259 | g_loss: 0.9060
# Epoch [    3/   25] | d_loss: 1.2090 | g_loss: 1.0326
# Epoch [    3/   25] | d_loss: 1.3394 | g_loss: 0.7442
# Epoch [    3/   25] | d_loss: 1.1756 | g_loss: 1.1473
# Epoch [    3/   25] | d_loss: 1.1686 | g_loss: 0.8283
# Epoch [    3/   25] | d_loss: 1.1800 | g_loss: 0.8582
# Epoch [    3/   25] | d_loss: 1.2152 | g_loss: 1.0736
# Epoch [    4/   25] | d_loss: 1.2292 | g_loss: 0.8631
# Epoch [    4/   25] | d_loss: 1.2484 | g_loss: 0.9987
# Epoch [    4/   25] | d_loss: 1.1555 | g_loss: 1.2066
# Epoch [    4/   25] | d_loss: 1.1278 | g_loss: 0.9520
# Epoch [    4/   25] | d_loss: 1.1437 | g_loss: 1.0167
# Epoch [    4/   25] | d_loss: 1.2960 | g_loss: 0.6835
# Epoch [    4/   25] | d_loss: 1.2599 | g_loss: 0.8812
# Epoch [    4/   25] | d_loss: 1.2717 | g_loss: 1.2303
# Epoch [    4/   25] | d_loss: 1.1643 | g_loss: 0.9010
# Epoch [    4/   25] | d_loss: 1.2824 | g_loss: 0.8129
# Epoch [    4/   25] | d_loss: 1.1311 | g_loss: 1.1312
# Epoch [    4/   25] | d_loss: 1.2036 | g_loss: 1.0674
# Epoch [    4/   25] | d_loss: 1.2520 | g_loss: 0.8035
# Epoch [    4/   25] | d_loss: 1.1501 | g_loss: 0.9231
# Epoch [    4/   25] | d_loss: 1.1602 | g_loss: 1.1942
# Epoch [    5/   25] | d_loss: 1.1897 | g_loss: 1.1075
# Epoch [    5/   25] | d_loss: 1.2769 | g_loss: 0.6727
# Epoch [    5/   25] | d_loss: 1.1981 | g_loss: 0.8620
# Epoch [    5/   25] | d_loss: 1.2915 | g_loss: 0.7608
# Epoch [    5/   25] | d_loss: 1.2587 | g_loss: 1.3609
# Epoch [    5/   25] | d_loss: 1.3252 | g_loss: 0.7681
# Epoch [    5/   25] | d_loss: 1.2556 | g_loss: 0.7903
# Epoch [    5/   25] | d_loss: 1.3423 | g_loss: 1.4907
# Epoch [    5/   25] | d_loss: 1.2744 | g_loss: 1.2671
# Epoch [    5/   25] | d_loss: 1.1675 | g_loss: 1.0283
# Epoch [    5/   25] | d_loss: 1.1675 | g_loss: 0.7753
# Epoch [    5/   25] | d_loss: 1.3239 | g_loss: 0.8393
# Epoch [    5/   25] | d_loss: 1.2360 | g_loss: 1.3731
# Epoch [    5/   25] | d_loss: 1.1271 | g_loss: 0.9904
# Epoch [    5/   25] | d_loss: 1.1935 | g_loss: 0.9119
# Epoch [    6/   25] | d_loss: 1.1380 | g_loss: 0.9675
# Epoch [    6/   25] | d_loss: 1.2117 | g_loss: 1.2533
# Epoch [    6/   25] | d_loss: 1.1660 | g_loss: 0.9531
# Epoch [    6/   25] | d_loss: 1.2234 | g_loss: 0.9019
# Epoch [    6/   25] | d_loss: 1.2142 | g_loss: 1.1810
# Epoch [    6/   25] | d_loss: 1.1420 | g_loss: 1.0682
# Epoch [    6/   25] | d_loss: 1.2087 | g_loss: 0.9406
# Epoch [    6/   25] | d_loss: 1.1604 | g_loss: 1.2307
# Epoch [    6/   25] | d_loss: 1.2424 | g_loss: 0.9418
# Epoch [    6/   25] | d_loss: 1.2294 | g_loss: 0.9990
# Epoch [    6/   25] | d_loss: 1.2086 | g_loss: 1.0034
# Epoch [    6/   25] | d_loss: 1.2898 | g_loss: 0.7534
# Epoch [    6/   25] | d_loss: 1.1749 | g_loss: 0.8588
# Epoch [    6/   25] | d_loss: 1.3011 | g_loss: 1.2361
# Epoch [    6/   25] | d_loss: 1.3413 | g_loss: 0.7458
# Epoch [    7/   25] | d_loss: 1.2359 | g_loss: 1.1137
# Epoch [    7/   25] | d_loss: 1.4379 | g_loss: 0.6541
# Epoch [    7/   25] | d_loss: 1.1789 | g_loss: 1.2036
# Epoch [    7/   25] | d_loss: 1.2983 | g_loss: 1.0311
# Epoch [    7/   25] | d_loss: 1.1199 | g_loss: 1.0985
# Epoch [    7/   25] | d_loss: 1.2119 | g_loss: 1.2913
# Epoch [    7/   25] | d_loss: 1.2216 | g_loss: 1.3372
# Epoch [    7/   25] | d_loss: 1.1284 | g_loss: 1.2065
# Epoch [    7/   25] | d_loss: 1.1745 | g_loss: 0.9722
# Epoch [    7/   25] | d_loss: 1.2308 | g_loss: 1.0134
# Epoch [    7/   25] | d_loss: 1.1497 | g_loss: 0.8854
# Epoch [    7/   25] | d_loss: 1.0635 | g_loss: 0.8868
# Epoch [    7/   25] | d_loss: 1.1803 | g_loss: 1.1743
# Epoch [    7/   25] | d_loss: 1.2395 | g_loss: 0.8753
# Epoch [    7/   25] | d_loss: 1.2857 | g_loss: 1.3470
# Epoch [    8/   25] | d_loss: 1.2507 | g_loss: 0.7891
# Epoch [    8/   25] | d_loss: 1.3967 | g_loss: 0.5074
# Epoch [    8/   25] | d_loss: 1.1417 | g_loss: 1.0896
# Epoch [    8/   25] | d_loss: 1.2054 | g_loss: 1.3057
# Epoch [    8/   25] | d_loss: 1.2046 | g_loss: 1.4290
# Epoch [    8/   25] | d_loss: 1.1960 | g_loss: 0.9598
# Epoch [    8/   25] | d_loss: 1.2296 | g_loss: 0.7871
# Epoch [    8/   25] | d_loss: 2.1649 | g_loss: 0.6734
# Epoch [    8/   25] | d_loss: 1.1399 | g_loss: 0.9105
# Epoch [    8/   25] | d_loss: 1.1766 | g_loss: 0.9288
# Epoch [    8/   25] | d_loss: 1.1715 | g_loss: 1.1524
# Epoch [    8/   25] | d_loss: 1.1331 | g_loss: 0.9626
# Epoch [    8/   25] | d_loss: 1.2870 | g_loss: 1.4911
# Epoch [    8/   25] | d_loss: 1.1787 | g_loss: 1.0568
# Epoch [    8/   25] | d_loss: 1.1860 | g_loss: 1.3778
# Epoch [    9/   25] | d_loss: 1.1534 | g_loss: 1.0838
# Epoch [    9/   25] | d_loss: 1.2383 | g_loss: 1.1046
# Epoch [    9/   25] | d_loss: 1.1870 | g_loss: 0.7796
# Epoch [    9/   25] | d_loss: 1.3090 | g_loss: 1.4576
# Epoch [    9/   25] | d_loss: 1.1422 | g_loss: 1.2030
# Epoch [    9/   25] | d_loss: 1.1543 | g_loss: 1.1442
# Epoch [    9/   25] | d_loss: 1.1876 | g_loss: 0.7019
# Epoch [    9/   25] | d_loss: 1.1441 | g_loss: 1.2456
# Epoch [    9/   25] | d_loss: 1.1484 | g_loss: 0.9384
# Epoch [    9/   25] | d_loss: 1.1080 | g_loss: 0.9345
# Epoch [    9/   25] | d_loss: 1.1372 | g_loss: 1.4039
# Epoch [    9/   25] | d_loss: 1.0310 | g_loss: 0.9874
# Epoch [    9/   25] | d_loss: 1.1536 | g_loss: 1.3163
# Epoch [    9/   25] | d_loss: 1.3240 | g_loss: 1.5307
# Epoch [    9/   25] | d_loss: 1.1732 | g_loss: 1.3486
# Epoch [   10/   25] | d_loss: 1.1469 | g_loss: 0.8791
# Epoch [   10/   25] | d_loss: 1.1149 | g_loss: 1.3632
# Epoch [   10/   25] | d_loss: 1.4717 | g_loss: 2.4804
# Epoch [   10/   25] | d_loss: 1.1173 | g_loss: 1.0954
# Epoch [   10/   25] | d_loss: 1.1623 | g_loss: 0.8427
# Epoch [   10/   25] | d_loss: 1.0706 | g_loss: 1.3490
# Epoch [   10/   25] | d_loss: 1.1414 | g_loss: 0.8069
# Epoch [   10/   25] | d_loss: 1.0834 | g_loss: 1.1845
# Epoch [   10/   25] | d_loss: 1.0862 | g_loss: 0.9167
# Epoch [   10/   25] | d_loss: 1.1176 | g_loss: 1.0549
# Epoch [   10/   25] | d_loss: 1.1691 | g_loss: 0.7472
# Epoch [   10/   25] | d_loss: 1.1957 | g_loss: 1.2306
# Epoch [   10/   25] | d_loss: 1.1091 | g_loss: 0.8819
# Epoch [   10/   25] | d_loss: 1.0705 | g_loss: 0.9189
# Epoch [   10/   25] | d_loss: 1.1603 | g_loss: 0.7744
# Epoch [   11/   25] | d_loss: 1.1980 | g_loss: 1.3728
# Epoch [   11/   25] | d_loss: 1.1404 | g_loss: 1.3214
# Epoch [   11/   25] | d_loss: 1.1290 | g_loss: 0.9072
# Epoch [   11/   25] | d_loss: 1.1178 | g_loss: 1.2608
# Epoch [   11/   25] | d_loss: 1.1072 | g_loss: 1.2206
# Epoch [   11/   25] | d_loss: 1.1353 | g_loss: 1.0970
# Epoch [   11/   25] | d_loss: 1.1303 | g_loss: 1.1213
# Epoch [   11/   25] | d_loss: 1.2007 | g_loss: 0.8697
# Epoch [   11/   25] | d_loss: 1.3174 | g_loss: 1.7693
# Epoch [   11/   25] | d_loss: 1.1524 | g_loss: 1.0819
# Epoch [   11/   25] | d_loss: 1.1883 | g_loss: 1.0763
# Epoch [   11/   25] | d_loss: 1.0460 | g_loss: 1.1263
# Epoch [   11/   25] | d_loss: 1.1342 | g_loss: 1.1024
# Epoch [   11/   25] | d_loss: 1.1177 | g_loss: 0.8913
# Epoch [   11/   25] | d_loss: 1.0475 | g_loss: 1.3112
# Epoch [   12/   25] | d_loss: 1.1748 | g_loss: 0.7278
# Epoch [   12/   25] | d_loss: 1.7236 | g_loss: 0.4431
# Epoch [   12/   25] | d_loss: 1.2231 | g_loss: 0.8306
# Epoch [   12/   25] | d_loss: 1.0606 | g_loss: 1.2905
# Epoch [   12/   25] | d_loss: 1.2663 | g_loss: 0.7127
# Epoch [   12/   25] | d_loss: 1.0374 | g_loss: 0.7794
# Epoch [   12/   25] | d_loss: 1.1688 | g_loss: 1.2897
# Epoch [   12/   25] | d_loss: 1.0747 | g_loss: 0.9366
# Epoch [   12/   25] | d_loss: 1.1588 | g_loss: 0.8817
# Epoch [   12/   25] | d_loss: 0.9226 | g_loss: 1.4748
# Epoch [   12/   25] | d_loss: 1.1462 | g_loss: 0.8614
# Epoch [   12/   25] | d_loss: 1.0562 | g_loss: 1.2682
# Epoch [   12/   25] | d_loss: 1.2226 | g_loss: 0.7579
# Epoch [   12/   25] | d_loss: 1.0143 | g_loss: 0.8965
# Epoch [   12/   25] | d_loss: 1.0810 | g_loss: 0.7061
# Epoch [   13/   25] | d_loss: 1.0994 | g_loss: 1.4105
# Epoch [   13/   25] | d_loss: 1.0576 | g_loss: 1.1589
# Epoch [   13/   25] | d_loss: 1.0194 | g_loss: 1.1154
# Epoch [   13/   25] | d_loss: 1.2287 | g_loss: 0.7252
# Epoch [   13/   25] | d_loss: 1.0648 | g_loss: 1.0006
# Epoch [   13/   25] | d_loss: 1.1571 | g_loss: 0.8749
# Epoch [   13/   25] | d_loss: 1.1779 | g_loss: 1.1011
# Epoch [   13/   25] | d_loss: 0.9990 | g_loss: 1.4509
# Epoch [   13/   25] | d_loss: 1.2528 | g_loss: 1.5562
# Epoch [   13/   25] | d_loss: 1.0449 | g_loss: 0.9823
# Epoch [   13/   25] | d_loss: 1.1204 | g_loss: 1.6240
# Epoch [   13/   25] | d_loss: 1.1399 | g_loss: 1.3786
# Epoch [   13/   25] | d_loss: 1.1411 | g_loss: 1.0497
# Epoch [   13/   25] | d_loss: 1.1427 | g_loss: 1.2537
# Epoch [   13/   25] | d_loss: 1.0954 | g_loss: 0.8717
# Epoch [   14/   25] | d_loss: 1.0771 | g_loss: 1.3444
# Epoch [   14/   25] | d_loss: 1.1130 | g_loss: 1.3307
# Epoch [   14/   25] | d_loss: 1.0443 | g_loss: 1.0810
# Epoch [   14/   25] | d_loss: 1.0856 | g_loss: 1.1185
# Epoch [   14/   25] | d_loss: 1.0958 | g_loss: 1.0289
# Epoch [   14/   25] | d_loss: 0.9985 | g_loss: 1.1285
# Epoch [   14/   25] | d_loss: 1.1544 | g_loss: 0.7259
# Epoch [   14/   25] | d_loss: 1.0407 | g_loss: 0.9991
# Epoch [   14/   25] | d_loss: 1.0367 | g_loss: 1.0924
# Epoch [   14/   25] | d_loss: 1.2015 | g_loss: 1.7939
# Epoch [   14/   25] | d_loss: 1.1246 | g_loss: 1.4068
# Epoch [   14/   25] | d_loss: 1.1209 | g_loss: 1.2360
# Epoch [   14/   25] | d_loss: 1.0677 | g_loss: 1.2537
# Epoch [   14/   25] | d_loss: 1.0758 | g_loss: 1.2960
# Epoch [   14/   25] | d_loss: 1.1227 | g_loss: 1.0132
# Epoch [   15/   25] | d_loss: 0.9977 | g_loss: 1.1020
# Epoch [   15/   25] | d_loss: 1.2151 | g_loss: 0.7710
# Epoch [   15/   25] | d_loss: 1.0919 | g_loss: 0.9948
# Epoch [   15/   25] | d_loss: 1.2194 | g_loss: 1.6582
# Epoch [   15/   25] | d_loss: 1.0600 | g_loss: 1.0434
# Epoch [   15/   25] | d_loss: 0.9907 | g_loss: 1.2999
# Epoch [   15/   25] | d_loss: 0.9531 | g_loss: 1.1177
# Epoch [   15/   25] | d_loss: 1.0155 | g_loss: 1.0113
# Epoch [   15/   25] | d_loss: 1.0039 | g_loss: 1.2835
# Epoch [   15/   25] | d_loss: 1.0862 | g_loss: 1.8223
# Epoch [   15/   25] | d_loss: 1.0218 | g_loss: 1.7033
# Epoch [   15/   25] | d_loss: 1.4337 | g_loss: 0.9610
# Epoch [   15/   25] | d_loss: 0.9300 | g_loss: 1.2091
# Epoch [   15/   25] | d_loss: 1.1260 | g_loss: 0.7698
# Epoch [   15/   25] | d_loss: 1.1188 | g_loss: 0.9205
# Epoch [   16/   25] | d_loss: 1.0433 | g_loss: 1.8375
# Epoch [   16/   25] | d_loss: 0.8927 | g_loss: 1.3094
# Epoch [   16/   25] | d_loss: 1.1295 | g_loss: 0.8833
# Epoch [   16/   25] | d_loss: 1.0292 | g_loss: 1.1305
# Epoch [   16/   25] | d_loss: 0.9366 | g_loss: 0.9770
# Epoch [   16/   25] | d_loss: 1.0688 | g_loss: 1.0946
# Epoch [   16/   25] | d_loss: 1.0428 | g_loss: 1.6684
# Epoch [   16/   25] | d_loss: 0.9750 | g_loss: 1.3196
# Epoch [   16/   25] | d_loss: 1.1111 | g_loss: 0.9912
# Epoch [   16/   25] | d_loss: 0.9863 | g_loss: 1.0888
# Epoch [   16/   25] | d_loss: 1.0665 | g_loss: 1.4791
# Epoch [   16/   25] | d_loss: 1.1002 | g_loss: 0.9611
# Epoch [   16/   25] | d_loss: 0.9756 | g_loss: 0.9622
# Epoch [   16/   25] | d_loss: 0.9616 | g_loss: 1.2532
# Epoch [   16/   25] | d_loss: 1.0497 | g_loss: 1.3114
# Epoch [   17/   25] | d_loss: 1.0151 | g_loss: 1.3034
# Epoch [   17/   25] | d_loss: 0.9716 | g_loss: 1.3747
# Epoch [   17/   25] | d_loss: 1.0883 | g_loss: 0.8755
# Epoch [   17/   25] | d_loss: 1.0203 | g_loss: 1.0293
# Epoch [   17/   25] | d_loss: 1.0449 | g_loss: 1.3053
# Epoch [   17/   25] | d_loss: 0.9971 | g_loss: 1.0916
# Epoch [   17/   25] | d_loss: 0.9837 | g_loss: 1.0484
# Epoch [   17/   25] | d_loss: 0.9093 | g_loss: 1.4307
# Epoch [   17/   25] | d_loss: 1.0237 | g_loss: 1.0885
# Epoch [   17/   25] | d_loss: 0.9660 | g_loss: 1.2282
# Epoch [   17/   25] | d_loss: 0.9549 | g_loss: 1.2765
# Epoch [   17/   25] | d_loss: 0.9307 | g_loss: 1.1299
# Epoch [   17/   25] | d_loss: 1.1936 | g_loss: 1.6900
# Epoch [   17/   25] | d_loss: 0.9928 | g_loss: 0.8779
# Epoch [   17/   25] | d_loss: 1.0061 | g_loss: 0.8874
# Epoch [   18/   25] | d_loss: 0.9307 | g_loss: 0.8067
# Epoch [   18/   25] | d_loss: 1.0443 | g_loss: 1.2672
# Epoch [   18/   25] | d_loss: 0.8886 | g_loss: 1.1664
# Epoch [   18/   25] | d_loss: 1.0953 | g_loss: 1.3778
# Epoch [   18/   25] | d_loss: 0.9904 | g_loss: 1.4648
# Epoch [   18/   25] | d_loss: 1.0142 | g_loss: 0.9024
# Epoch [   18/   25] | d_loss: 1.0441 | g_loss: 1.1475
# Epoch [   18/   25] | d_loss: 0.8752 | g_loss: 1.5897
# Epoch [   18/   25] | d_loss: 0.9112 | g_loss: 1.0290
# Epoch [   18/   25] | d_loss: 2.2754 | g_loss: 3.5032
# Epoch [   18/   25] | d_loss: 0.8474 | g_loss: 1.3739
# Epoch [   18/   25] | d_loss: 1.0288 | g_loss: 1.2020
# Epoch [   18/   25] | d_loss: 0.9950 | g_loss: 1.1985
# Epoch [   18/   25] | d_loss: 1.2171 | g_loss: 1.0963
# Epoch [   18/   25] | d_loss: 1.0013 | g_loss: 1.1864
# Epoch [   19/   25] | d_loss: 0.9687 | g_loss: 1.5430
# Epoch [   19/   25] | d_loss: 1.0109 | g_loss: 1.7562
# Epoch [   19/   25] | d_loss: 0.9300 | g_loss: 1.3625
# Epoch [   19/   25] | d_loss: 1.0132 | g_loss: 0.9788
# Epoch [   19/   25] | d_loss: 0.9336 | g_loss: 1.4939
# Epoch [   19/   25] | d_loss: 1.0399 | g_loss: 1.8199
# Epoch [   19/   25] | d_loss: 0.9079 | g_loss: 1.3962
# Epoch [   19/   25] | d_loss: 0.8720 | g_loss: 1.5912
# Epoch [   19/   25] | d_loss: 0.9925 | g_loss: 1.7779
# Epoch [   19/   25] | d_loss: 0.8665 | g_loss: 1.1793
# Epoch [   19/   25] | d_loss: 0.9622 | g_loss: 1.0627
# Epoch [   19/   25] | d_loss: 0.9654 | g_loss: 1.2578
# Epoch [   19/   25] | d_loss: 1.1814 | g_loss: 2.3535
# Epoch [   19/   25] | d_loss: 0.9250 | g_loss: 1.0576
# Epoch [   19/   25] | d_loss: 0.9663 | g_loss: 1.1827
# Epoch [   20/   25] | d_loss: 0.8199 | g_loss: 1.2069
# Epoch [   20/   25] | d_loss: 0.9896 | g_loss: 1.8227
# Epoch [   20/   25] | d_loss: 1.1636 | g_loss: 2.1524
# Epoch [   20/   25] | d_loss: 0.8948 | g_loss: 1.2844
# Epoch [   20/   25] | d_loss: 1.0156 | g_loss: 1.6469
# Epoch [   20/   25] | d_loss: 1.0553 | g_loss: 1.7267
# Epoch [   20/   25] | d_loss: 0.9977 | g_loss: 0.8782
# Epoch [   20/   25] | d_loss: 1.2420 | g_loss: 0.8296
# Epoch [   20/   25] | d_loss: 0.9896 | g_loss: 1.8154
# Epoch [   20/   25] | d_loss: 1.0738 | g_loss: 1.9751
# Epoch [   20/   25] | d_loss: 1.0478 | g_loss: 1.5352
# Epoch [   20/   25] | d_loss: 1.0683 | g_loss: 1.9608
# Epoch [   20/   25] | d_loss: 1.0921 | g_loss: 1.6408
# Epoch [   20/   25] | d_loss: 0.8876 | g_loss: 1.2575
# Epoch [   20/   25] | d_loss: 0.9051 | g_loss: 1.6210
# Epoch [   21/   25] | d_loss: 1.0777 | g_loss: 0.7953
# Epoch [   21/   25] | d_loss: 0.9193 | g_loss: 1.6574
# Epoch [   21/   25] | d_loss: 0.8911 | g_loss: 1.6350
# Epoch [   21/   25] | d_loss: 0.8357 | g_loss: 1.8208
# Epoch [   21/   25] | d_loss: 0.8448 | g_loss: 1.1826
# Epoch [   21/   25] | d_loss: 0.9881 | g_loss: 1.3166
# Epoch [   21/   25] | d_loss: 0.9578 | g_loss: 1.4227
# Epoch [   21/   25] | d_loss: 0.9574 | g_loss: 0.9750
# Epoch [   21/   25] | d_loss: 0.8275 | g_loss: 1.0903
# Epoch [   21/   25] | d_loss: 1.0228 | g_loss: 0.8297
# Epoch [   21/   25] | d_loss: 0.9626 | g_loss: 1.6127
# Epoch [   21/   25] | d_loss: 1.0066 | g_loss: 1.1029
# Epoch [   21/   25] | d_loss: 1.3257 | g_loss: 0.9605
# Epoch [   21/   25] | d_loss: 0.9379 | g_loss: 1.2757
# Epoch [   21/   25] | d_loss: 1.0075 | g_loss: 1.2101
# Epoch [   22/   25] | d_loss: 0.9794 | g_loss: 1.2495
# Epoch [   22/   25] | d_loss: 0.9987 | g_loss: 0.8993
# Epoch [   22/   25] | d_loss: 0.9139 | g_loss: 1.2496
# Epoch [   22/   25] | d_loss: 0.8161 | g_loss: 1.1994
# Epoch [   22/   25] | d_loss: 1.0418 | g_loss: 0.8747
# Epoch [   22/   25] | d_loss: 0.9297 | g_loss: 1.1938
# Epoch [   22/   25] | d_loss: 0.9274 | g_loss: 1.5981
# Epoch [   22/   25] | d_loss: 0.9936 | g_loss: 1.1608
# Epoch [   22/   25] | d_loss: 1.0027 | g_loss: 2.0499
# Epoch [   22/   25] | d_loss: 1.1621 | g_loss: 0.8104
# Epoch [   22/   25] | d_loss: 1.0012 | g_loss: 1.8189
# Epoch [   22/   25] | d_loss: 0.9046 | g_loss: 1.0581
# Epoch [   22/   25] | d_loss: 0.8915 | g_loss: 1.0088
# Epoch [   22/   25] | d_loss: 0.8648 | g_loss: 1.4470
# Epoch [   22/   25] | d_loss: 1.0795 | g_loss: 2.0306
# Epoch [   23/   25] | d_loss: 0.9453 | g_loss: 1.1642
# Epoch [   23/   25] | d_loss: 0.9486 | g_loss: 1.8355
# Epoch [   23/   25] | d_loss: 0.8893 | g_loss: 1.0539
# Epoch [   23/   25] | d_loss: 0.7914 | g_loss: 1.3262
# Epoch [   23/   25] | d_loss: 0.9602 | g_loss: 1.6360
# Epoch [   23/   25] | d_loss: 0.7686 | g_loss: 1.5987
# Epoch [   23/   25] | d_loss: 0.9237 | g_loss: 1.3039
# Epoch [   23/   25] | d_loss: 0.9341 | g_loss: 1.8580
# Epoch [   23/   25] | d_loss: 1.0088 | g_loss: 1.7742
# Epoch [   23/   25] | d_loss: 0.9765 | g_loss: 1.0465
# Epoch [   23/   25] | d_loss: 0.8599 | g_loss: 1.2822
# Epoch [   23/   25] | d_loss: 0.8372 | g_loss: 1.5245
# Epoch [   23/   25] | d_loss: 1.0453 | g_loss: 1.1048
# Epoch [   23/   25] | d_loss: 1.0651 | g_loss: 1.9601
# Epoch [   23/   25] | d_loss: 1.1431 | g_loss: 2.4092
# Epoch [   24/   25] | d_loss: 1.3650 | g_loss: 0.5677
# Epoch [   24/   25] | d_loss: 0.9184 | g_loss: 1.1749
# Epoch [   24/   25] | d_loss: 0.9504 | g_loss: 2.1270
# Epoch [   24/   25] | d_loss: 0.9811 | g_loss: 2.1084
# Epoch [   24/   25] | d_loss: 0.7916 | g_loss: 1.4714
# Epoch [   24/   25] | d_loss: 1.1392 | g_loss: 0.8857
# Epoch [   24/   25] | d_loss: 0.9895 | g_loss: 1.8803
# Epoch [   24/   25] | d_loss: 0.9456 | g_loss: 1.8784
# Epoch [   24/   25] | d_loss: 0.8389 | g_loss: 1.4309
# Epoch [   24/   25] | d_loss: 0.9024 | g_loss: 1.9313
# Epoch [   24/   25] | d_loss: 0.8650 | g_loss: 1.0917
# Epoch [   24/   25] | d_loss: 0.9252 | g_loss: 1.3640
# Epoch [   24/   25] | d_loss: 0.9431 | g_loss: 0.8115
# Epoch [   24/   25] | d_loss: 0.9793 | g_loss: 1.0277
# Epoch [   24/   25] | d_loss: 0.8495 | g_loss: 1.3627
# Epoch [   25/   25] | d_loss: 0.8857 | g_loss: 1.1411
# Epoch [   25/   25] | d_loss: 0.8161 | g_loss: 1.7785
# Epoch [   25/   25] | d_loss: 0.9430 | g_loss: 1.3419
# Epoch [   25/   25] | d_loss: 0.9649 | g_loss: 1.9251
# Epoch [   25/   25] | d_loss: 0.9474 | g_loss: 1.1099
# Epoch [   25/   25] | d_loss: 0.8514 | g_loss: 1.4882
# Epoch [   25/   25] | d_loss: 0.9718 | g_loss: 0.9492
# Epoch [   25/   25] | d_loss: 0.9194 | g_loss: 1.2114
# Epoch [   25/   25] | d_loss: 0.8860 | g_loss: 1.0923
# Epoch [   25/   25] | d_loss: 0.8757 | g_loss: 1.3082
# Epoch [   25/   25] | d_loss: 1.1870 | g_loss: 2.8732
# Epoch [   25/   25] | d_loss: 0.8504 | g_loss: 1.4066
# Epoch [   25/   25] | d_loss: 0.8515 | g_loss: 1.9688
# Epoch [   25/   25] | d_loss: 0.8479 | g_loss: 1.2699
# Epoch [   25/   25] | d_loss: 0.8279 | g_loss: 1.4479

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
# 1. my model is not super big, and I could use more conv and deconv layers to make a more powerfull network and learn more features in the dataset, meanwhile the training time will be longer.
# 2. As it's hinted, the dataset is biased, the original content of the dataset determines the outcome of the model after training; to get better representation of the population, a more diversed dataset would be ideal.
# 3. It's hard to visualize GAN performance only with numbers, I could also save samples with more checkpoints and compare the quality of the generated images using human eye to optimize the number of epochs.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
